# %%
# %load_ext autoreload
# %autoreload 2

from DarkMatter import *
# Out:
# Welcome to JupyROOT 6.26/08

# %%
input_file = "sigvLineNLL_table.csv"
f = open(const.REF_DIR+f"/{input_file}")

lines = []
for line in f.readlines():
    l = line.split(",")
    temp = []
    for s in l:
        s = s.replace("'", '')
        try:
            temp.append(float(s))
        except:
            print(s)
            continue
    if len(temp)>0:
        lines.append(temp)
# Out:
# Index
# Mass
# sigvLineNLL

# %%
lines = np.asarray(lines)

# %%
tab = Table(lines, names = ["i", "mass", "signu"])
np.save(const.REF_DIR+f"/sigvLineNLL.npy",tab)

# %%
lines
# Out:
# [[0.0, 800.0, 3.0114e-27],
#  [1.0, 1000.0, 3.4863e-27],
#  [2.0, 1250.0, 4.5299e-27],
#  [3.0, 1500.0, 6.543e-27],
#  [4.0, 1750.0, 1.1012e-26],
#  [5.0, 2000.0, 2.4221e-26],
#  [6.0, 2250.0, 1.0324e-25],
#  [7.0, 2500.0, 8.1745e-24],
#  [8.0, 2750.0, 6.5726e-26],
#  [9.0, 3000.0, 1.7867e-26],
#  [10.0, 3250.0, 8.2136e-27],
#  [11.0, 3500.0, 4.7545e-27],
#  [12.0, 3750.0, 3.1442e-27],
#  [13.0, 4000.0, 2.2725e-27],
#  [14.0, 4250.0, 1.7526e-27],
#  [15.0, 4500.0, 1.4218e-27],
#  [16.0, 4750.0, 1.2022e-27],
#  [17.0, 5000.0, 1.053e-27],
#  [18.0, 5250.0, 9.513e-28],
#  [19.0, 5500.0, 8.839e-28],
#  [20.0, 5750.0, 8.4299e-28],
#  [21.0, 6000.0, 8.2421e-28],
#  [22.0, 6250.0, 8.2566e-28],
#  [23.0, 6500.0, 8.4746e-28],
#  [24.0, 6750.0, 8.9181e-28],
#  [25.0, 7000.0, 9.6347e-28],
#  [26.0, 7250.0, 1.071e-27],
#  [27.0, 7500.0, 1.229e-27],
#  [28.0, 7750.0, 1.4634e-27],
#  [29.0, 8000.0, 1.8219e-27],
#  [30.0, 8250.0, 2.3998e-27],
#  [31.0, 8500.0, 3.4101e-27],
#  [32.0, 8750.0, 5.4138e-27],
#  [33.0, 9000.0, 1.0321e-26],
#  [34.0, 9250.0, 2.8602e-26],
#  [35.0, 9500.0, 2.9786e-25],
#  [36.0, 9750.0, 1.7826e-25],
#  [37.0, 10000.0, 2.2584e-26],
#  [38.0, 10500.0, 4.2385e-27],
#  [39.0, 11000.0, 1.7303e-27],
#  [40.0, 11500.0, 9.4877e-28],
#  [41.0, 12000.0, 6.1196e-28],
#  [42.0, 12500.0, 4.3898e-28],
#  [43.0, 13000.0, 3.4021e-28],
#  [44.0, 13500.0, 2.8011e-28],
#  [45.0, 14000.0, 2.4247e-28],
#  [46.0, 14500.0, 2.1919e-28],
#  [47.0, 15000.0, 2.0606e-28],
#  [48.0, 15500.0, 2.0093e-28],
#  [49.0, 16000.0, 2.0302e-28],
#  [50.0, 16500.0, 2.1257e-28],
#  [51.0, 17000.0, 2.3103e-28],
#  [52.0, 17500.0, 2.6146e-28],
#  [53.0, 18000.0, 3.0979e-28],
def file_conversion(input_file, output_file):
    f = open(const.REF_DIR+f"/{input_file}")

    lines = []
    for line in f.readlines():
        l = line.split(",")
        temp = []
        for s in l:
            s = s.replace("'", '')
            try:
                temp.append(float(s))
            except:
                print(s)
                continue
        if len(temp)>0:
            lines.append(temp)

    lines = np.asarray(lines)
    print(lines)
    tab = Table(lines, names = ["x", "dNdE", "mass"])
    np.save(const.REF_DIR+f"/{output_file}.npy",tab)
    
def change_file(new, old):
    os.system("mv "+const.REF_DIR+f"/wino_dnde.npy "+const.REF_DIR+f"/{old}.npy" )
    os.system("mv "+const.REF_DIR+f"/{new}.npy "+const.REF_DIR+f"/wino_dnde.npy" )

# %%
file_conversion("dnde_results_LoMass.csv", "wino_dnde_res_lo")
# Out:
# x
# dnde_result
# mass
#
# [[1.00000000e-04 1.33312993e+03 8.00000000e+02]
#  [1.20679264e-04 1.29284158e+03 8.00000000e+02]
#  [1.45634848e-04 1.24786848e+03 8.00000000e+02]
#  ...
#  [6.86648845e-01 2.05639716e-04 5.55000000e+04]
#  [8.28642773e-01 2.90732089e-04 5.55000000e+04]
#  [1.00000000e+00 2.97146627e-05 5.55000000e+04]]

# %%
change_file("wino_dnde_res_lo", "wino_dnde_res_hi")

# %%
data = WINOspectra(return_table=True)

mass = list(set(data["mass"]))

mass.sort()

# %%
mle = Likelihood.combinedUpperLimits("wino", package="EventDisplay", dwarfs=const.ListOfDwarf, method=2, ext=True, DM_spectra="WINO",
                            mass=mass[::5], addTheta=False, averagedIRF=True, useBias=True, 
                            correction=True, bkgModel="gaus", filename="wino_nlo_hi_combined",
                            )
# Out:
# ==================================================
# [Log] Package      : EventDisplay
# [Log] # of Dwarfs  : 17
# [Log] Channel      : wino
# [Log] Dimention    : 1
# [Log] Background   : Gaussian (gaus)
# [Log] Dispersion   : Etr vs ratio
# [Log] Minimum mass : 56000 GeV
# [Log] Maximum mass : 192 TeV
# ==================================================
#   0%|          | 0/26 [00:00<?, ?it/s]
# [Log] Upper limits are saved in '/Users/dtak/Research/DarkMatter/Output/wino_nlo_hi_combined.npy'
# Warning in <TROOT::Append>: Replacing existing TH1: hg_1D (Potential memory leak).

# %%
change_file("wino_dnde_res_lo", "wino_dnde_res_hi")

data = WINOspectra(return_table=True)

mass = list(set(data["mass"]))

mass.sort()

mle = Likelihood.combinedUpperLimits("wino", package="EventDisplay", dwarfs=const.ListOfDwarf, method=2, ext=True, DM_spectra="WINO",
                            mass=mass[::5], addTheta=False, averagedIRF=True, useBias=True, 
                            correction=True, bkgModel="gaus", filename="wino_nlo_lo_combined",
                            )
# Out:
# ==================================================
# [Log] Package      : EventDisplay
# [Log] # of Dwarfs  : 17
# [Log] Channel      : wino
# [Log] Dimention    : 1
# [Log] Background   : Gaussian (gaus)
# [Log] Dispersion   : Etr vs ratio
# [Log] Minimum mass : 800 GeV
# [Log] Maximum mass : 54 TeV
# ==================================================
#   0%|          | 0/26 [00:00<?, ?it/s]
# [Log] Upper limits are saved in '/Users/dtak/Research/DarkMatter/Output/wino_nlo_lo_combined.npy'

# %%
ebins = np.linspace(1, 7, 101)
uls = []

change_file("wino_dnde_res_lo", "wino_dnde_res_hi")

data = WINOspectra(return_table=True)

mass = list(set(data["mass"]))

mass.sort()

for m in mass:
    diff = ebins[np.argmin(abs(m-10**ebins))]-np.log10(m)
    new_ebins = 10**(ebins-diff)
    
    mle = Likelihood.combinedUpperLimits("wino", package="EventDisplay", dwarfs=const.ListOfDwarf, method=2, ext=True, DM_spectra="WINO",
                            mass=[m], addTheta=False, averagedIRF=True, useBias=True, statistic="binned",
                            correction=True, bkgModel="gaus", filename=False, energyEdges=new_ebins,
                            )
    uls.append(mle)
    
change_file("wino_dnde_res_hi", "wino_dnde_res_lo")

data = WINOspectra(return_table=True)

mass = list(set(data["mass"]))

mass.sort()

for m in mass:
    diff = ebins[np.argmin(abs(m-10**ebins))]-np.log10(m)
    new_ebins = 10**(ebins-diff)
    
    mle = Likelihood.combinedUpperLimits("wino", package="EventDisplay", dwarfs=const.ListOfDwarf, method=2, ext=True, DM_spectra="WINO",
                            mass=[m], addTheta=False, averagedIRF=True, useBias=True, statistic="binned",
                            correction=True, bkgModel="gaus", filename=False, energyEdges=new_ebins,
                            )
    uls.append(mle)
# Out:
# ==================================================
# [Log] Package      : EventDisplay
# [Log] # of Dwarfs  : 17
# [Log] Channel      : wino
# [Log] Dimention    : 1
# [Log] Background   : Gaussian (gaus)
# [Log] Dispersion   : Etr vs ratio
# [Log] Minimum mass : 800 GeV
# [Log] Maximum mass : 1 TeV
# ==================================================
#   0%|          | 0/1 [00:00<?, ?it/s]
# ==================================================
# [Log] Package      : EventDisplay
# [Log] # of Dwarfs  : 17
# [Log] Channel      : wino
# [Log] Dimention    : 1
# [Log] Background   : Gaussian (gaus)
# [Log] Dispersion   : Etr vs ratio
# [Log] Minimum mass : 2000 GeV
# [Log] Maximum mass : 2 TeV
# ==================================================
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AbortSignal                               Traceback (most recent call last)
# Cell In [111], line 7
#       4 diff = ebins[np.argmin(abs(m-10**ebins))]-np.log10(m)
#       5 new_ebins = 10**(ebins-diff)
# ----> 7 mle = Likelihood.combinedUpperLimits("wino", package="EventDisplay", dwarfs=const.ListOfDwarf, method=2, ext=True, DM_spectra="WINO",
#       8                         mass=[m], addTheta=False, averagedIRF=True, useBias=True, statistic="binned",
#       9                         correction=True, bkgModel="gaus", filename=False, energyEdges=new_ebins,
#      10                         )
#      11 uls.append(mle)
#
# File ~/Research/scripts/dm_analysis/DarkMatter/Likelihood/combinedUL.py:185, in combinedUpperLimits(channel, package, dwarfs, addTheta, averagedIRF, method, version, jSeed, filename, seed, overWrite, th2Cut, ext, sys, mass, bkgModel, verbosity, filter_he, returnTS, **kwargs)
#     177     mle = MLE(dwarf, M, package, channel=channel, irf=irf[dwarf], jProfile=jProfile[dwarf], jArray=True,
#     178             th2Cut=th2Cut, addTheta=addTheta, ext=ext,
#     179             averagedIRF=averagedIRF, version=version, tau=tau[dwarf],
#     180             seed=i+5,
#     181             bkgModel=bkgModel, filter_he=filter_he,
#     182             verbose=(True if verbosity>2 else False), **kwargs)
#     183     stackedMLE[dwarf] = mle
# --> 185 ul_i, ts_i = combinedMinuit(stackedMLE, signu0 = mle.signu0, channel=channel, verbose=max(verbosity-1, 0), statistic = kwargs.get("statistic", "unbinned"))
#     187 if ul_i != -1 and ts_i != -1:
#     188     ul.append([M, ul_i])
#
# File ~/Research/scripts/dm_analysis/DarkMatter/Likelihood/combinedUL.py:823, in combinedMinuit(stackedMLE, channel, seed, signu0, statistic, verbose)
#     821 # For calculating an upper limit
#     822 fit.SetErrorDef(2.71/2)
# --> 823 fit.mnexcm("MIGRAD", arglist, 2, ierflg);
#     825 # Estimate an upper limit with profile likelihood
#     826 istat = ctypes.c_int(12)
#
# AbortSignal: void TMinuit::mnexcm(const char* comand, double* plist, int llist, int& ierflg) =>
#     AbortSignal: abort from C++; program state was reset
#  NEW MINIMUM FOUND.  GO BACK TO MINIMIZATION STEP.
#  =================================================
#                                                   V
#                                                   V
#                                                   V
#                                                VVVVVVV
#                                                 VVVVV
#                                                  VVV
#                                                   V
#
# [/opt/local/libexec/root6/lib/root/libCore.6.26.08.so] TUnixSystem::DispatchSignals(ESignals) (no debug info)
# [/usr/lib/system/libsystem_platform.dylib] _sigtramp (no debug info)
# [/usr/lib/system/libsystem_pthread.dylib] pthread_kill (no debug info)
# [/usr/lib/system/libsystem_c.dylib] abort (no debug info)
# [/usr/lib/libc++abi.dylib] __cxxabiv1::__aligned_malloc_with_fallback(unsigned long) (no debug info)
# [/usr/lib/libc++abi.dylib] demangling_terminate_handler() (no debug info)
# [/usr/lib/libobjc.A.dylib] _objc_terminate() (no debug info)
# [/usr/lib/libc++abi.dylib] std::__terminate(void (*)()) (no debug info)
# [/usr/lib/libc++abi.dylib] __cxa_get_exception_ptr (no debug info)
# [/usr/lib/libc++abi.dylib] __cxxabiv1::exception_cleanup_func(_Unwind_Reason_Code, _Unwind_Exception*) (no debug info)
# [<unknown binary>] (no debug info)
# [/opt/local/libexec/root6/lib/root/libMinuit.6.26.08.so] TMinuit::Eval(int, double*, double&, double*, int) (no debug info)
# [/opt/local/libexec/root6/lib/root/libMinuit.6.26.08.so] TMinuit::mnline(double*, double, double*, double, double) (no debug info)
# [/opt/local/libexec/root6/lib/root/libMinuit.6.26.08.so] TMinuit::mnmigr() (no debug info)
# [/opt/local/libexec/root6/lib/root/libMinuit.6.26.08.so] TMinuit::mnexcm(char const*, double*, int, int&) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy_backend3_10.6.26.08.so] WrapperCall(long, unsigned long, void*, void*, void*) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy3_10.6.26.08.so] CPyCppyy::(anonymous namespace)::VoidExecutor::Execute(long, void*, CPyCppyy::CallContext*) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy3_10.6.26.08.so] CPyCppyy::CPPMethod::ExecuteFast(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy3_10.6.26.08.so] CPyCppyy::CPPMethod::ExecuteProtected(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy3_10.6.26.08.so] CPyCppyy::CPPMethod::Execute(void*, long, CPyCppyy::CallContext*) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy3_10.6.26.08.so] CPyCppyy::CPPMethod::Call(CPyCppyy::CPPInstance*&, _object*, _object*, CPyCppyy::CallContext*) (no debug info)
# [/opt/local/libexec/root6/lib/root/libcppyy3_10.6.26.08.so] CPyCppyy::(anonymous namespace)::mp_call(CPyCppyy::CPPOverload*, _object*, _object*) (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyObject_MakeTpCall (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] builtin_exec (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] cfunction_vectorcall_FASTCALL (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] method_vectorcall_O (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] method_vectorcall (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] PyVectorcall_Call (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] method_vectorcall (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] gen_send_ex2 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/lib/python3.10/lib-dynload/_asyncio.cpython-310-darwin.so] task_step_impl (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/lib/python3.10/lib-dynload/_asyncio.cpython-310-darwin.so] task_step (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/lib/python3.10/lib-dynload/_asyncio.cpython-310-darwin.so] task_wakeup (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] cfunction_vectorcall_O (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyObject_VectorcallTstate.4657 (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] context_run (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] cfunction_vectorcall_FASTCALL_KEYWORDS (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] method_vectorcall (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] builtin_exec (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] cfunction_vectorcall_FASTCALL (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] call_function (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_EvalFrameDefault (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] _PyEval_Vector (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] pymain_run_module (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] pymain_run_python (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] Py_RunMain (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] pymain_main (no debug info)
# [/Users/dtak/Software/miniconda3/envs/dm/bin/python3.10] main (no debug info)
# [/usr/lib/dyld] start (no debug info)
# libc++abi: terminating with uncaught exception of type CPyCppyy::PyException: python exception
#  *** Break *** abort

# %%
mle
# Out:
# [800.0, array(-24.726089)]

# %%
uls = uls.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [93], line 1
# ----> 1 uls = uls.tolist()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
uls = np.asarray(uls)

# %%
uls2 = copy.copy(uls)

# %%
uls.remove(uls[14])

# %%
uls = np.asarray(uls)

# %%
np.save(const.OUTPUT_DIR+"wino_nlo_matt", uls[:,0])

# %%
sig = []
for i in np.arange(10, 200, step=10):
    mle = Likelihood.MLE("Segue_1", 2000, DM_spectra="wino", channel="wino", ext=True, bkgModel="gaus", 
                     energyEdges = np.geomspace(10, 10**7, i))
    mle.minuit(method=2)
    sig.append(mle.signu_ul)
# Out:
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Error] The upper limit is not estimated (M=2.000 TeV).
# [Log, Result] TS = 766.50 (M=2000 GeV)
# [Log, Result] <σν> = 10^(-22.680 +/- 0.027)
# [Log, Result] b = 10450 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = 3.54 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.041) (equivalent to 9.11e-25)
# [Log, Result] b = 11217 +/- 150 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.370) (equivalent to 4.26e-25)
# [Log, Result] b = 11290 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.821) (equivalent to 1.51e-25)
# [Log, Result] b = 11291 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.537) (equivalent to 2.90e-25)
# [Log, Result] b = 11291 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.697) (equivalent to 2.01e-25)
# [Log, Result] b = 11291 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-25.099) (equivalent to 7.97e-26)
# [Log, Result] b = 11291 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.797) (equivalent to 1.59e-25)
# [Log, Result] b = 11291 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.124) (equivalent to 7.52e-25)
# [Log, Result] b = 11291 +/- 146 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.390) (equivalent to 4.07e-25)
# [Log, Result] b = 11291 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] The signal (M=2000 GeV) is not significant (TS < 1).
# [Log, Result] <σν> (95& upper limit) = 10^(-25.135) (equivalent to 7.32e-26)
# [Log, Result] b = 11290 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.023) (equivalent to 9.48e-25)
# [Log, Result] b = 11293 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] The signal (M=2000 GeV) is not significant (TS < 1).
# [Log, Result] <σν> (95& upper limit) = 10^(-24.904) (equivalent to 1.25e-25)
# [Log, Result] b = 11290 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.386) (equivalent to 4.11e-25)
# [Log, Result] b = 11289 +/- 142 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.577) (equivalent to 2.65e-25)
# [Log, Result] b = 11291 +/- 141 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] The signal (M=2000 GeV) is not significant (TS < 1).
# [Log, Result] <σν> (95& upper limit) = 10^(-24.691) (equivalent to 2.04e-25)
# [Log, Result] b = 11290 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] TS = -0.00 (M=2000 GeV)
# [Log, Result] <σν> (95& upper limit) = 10^(-24.779) (equivalent to 1.66e-25)
# [Log, Result] b = 11290 +/- 138 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] The signal (M=2000 GeV) is not significant (TS < 1).
# [Log, Result] <σν> (95& upper limit) = 10^(-24.346) (equivalent to 4.51e-25)
# [Log, Result] b = 11290 +/- 139 (null value: 11291)
# [Log] Initializing... (EventDisplay)
# [Log] Step 1: Instrument response functions are imported.
# [Log] Step 2: Events are loaded.
# [Log] Step 3: A source model is loaded.
# [Log] Step 4: Assigning probabilities for each event...
#
# [Warning] 1 events have p_bkg of 0. They are ignored when calculating the likelihood.
#       Energy
# ------------------
# 62290.446171057825
#
#
# [Log] Step 4: A temporary file for minimization is generated.
# [Log] Initialization is done. Run minuite.
# [Log, Result] The signal (M=2000 GeV) is not significant (TS < 1).
# [Log, Result] <σν> (95& upper limit) = 10^(-24.383) (equivalent to 4.14e-25)
# [Log, Result] b = 11290 +/- 139 (null value: 11291)

# %%
plt.plot(data["mass"], data["signu"])

# %%
plotULcurve("wino_nlo_lo_combined", add_input="wino_nlo_hi_combined", label="WINO (17dSphs; 638hrs; standard)", units="TeV")
plotULcurve("wino_nlo_matt", label="WINO (17dSphs; 638hrs; centered)", units="TeV")
plt.axvline(2.8, color="r", ls="--", label="Thermal relic mass")
plt.plot(data["mass"]/1000, data["signu"], color="k")
plt.legend(loc=2, fontsize=10)

# %% [markdown]
# # Check John's Idea

# %%
plotULcurve("wino_nlo", label="WINO (Segue 1; 126 hours; unbinned)")
plotULcurve("wino_nlo_lo_binned", label="WINO (Segue 1; 126 hours; binned)")
plotULcurve("wino_nlo_lo_c", label="WINO (Segue 1; 126 hours; unbinned)")
plotULcurve("wino_nlo_lo_binned_c", label="WINO (Segue 1; 126 hours; binned)")

plotULcurve("wino_nlo_hi", color="C0")
plotULcurve("wino_nlo_binned_hi", color="C1", addRelic=True)

# %% [markdown]
# # Check # of bins

# %%
sig_3 = []
for i in np.arange(10, 201, step=5):
    mle = Likelihood.MLE("Segue_1", 3000, DM_spectra="wino", channel="wino", ext=True, bkgModel="gaus", 
                     energyEdges = np.geomspace(10, 10**7, i), verbose=False)
    mle.minuit(method=2)
    sig_3.append(mle.signu_ul)
# Out:
# [Log, Error] The upper limit is not estimated (M=3.000 TeV).

# %%
Likelihood.EventDisplay.plotData("UMa_II", ext=True, energyEdges = np.geomspace(10, 10**7, 100))

# %%
plt.plot(np.arange(10, 201, step=5), sig, label="2 TeV")
plt.plot(np.arange(10, 201, step=5), sig_3, label="3 TeV")

# %% [markdown]
# # Shift bins

# %%
sig_s = []
for i in range(60):
    mle = Likelihood.MLE("Segue_1", 3000, DM_spectra="wino", channel="wino", ext=True, bkgModel="gaus", 
                     energyEdges = np.logspace(1+0.001*i, 7+0.01*i, 101), verbose=False)
    mle.minuit(method=2)
    sig_s.append(mle.signu_ul)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 2061

# %%
plt.plot(range(60), sig_s)

# %%
mle = Likelihood.calcExpectedLimits("Segue_1", "wino", package="EventDisplay", method=2, ext=True, DM_spectra="WINO",
                            mass=mass, addTheta=False, averagedIRF=True, useBias=True, jSeed=defaultNum["Segue_1"],
                            correction=True, bkgModel="gaus", filename="wino_nlo_exp")
# Out:
# ==================================================
# [Log] Package      : EventDisplay
# [Log] Dwarf        : Segue_1
# [Log] Channel      : wino
# [Log] Dispersion   : Etr vs ratio
# [Log] Minimum mass : 800 GeV
# [Log] Maximum mass : 56 TeV
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 mle = Likelihood.calcExpectedLimits("Segue_1", "wino", package="EventDisplay", method=2, ext=True, DM_spectra="WINO",
#       2                             mass=mass, addTheta=False, averagedIRF=True, useBias=True, jSeed=defaultNum["Segue_1"],
#       3                             correction=True, bkgModel="gaus", filename="wino_nlo_exp")
#
# File ~/Research/scripts/dm_analysis/DarkMatter/Likelihood/upperlimit.py:349, in calcExpectedLimits(dwarf, channel, package, irf, jProfile, jArray, version, th2Cut, addTheta, averagedIRF, method, fix_b, filename, seed, jSeed, mass, bkgModel, ext, test, verbosity, runs, multi, **kwargs)
#     346     if jArray and jSeed == -1:
#     347         jSeed = random.randrange(0, JProfile.goodPropNum(dwarf)-1)
# --> 349     jProfile = JProfile.generateConvolvedJ(dwarf, package, irf=importedIRF, version=version, return_array=True, seed = jSeed, verbose=False,  th2Cut=th2Cut, ext=ext)
#     351 hSignal = {}
#     352 for i, M in enumerate(mass):
#
# File ~/Research/scripts/dm_analysis/DarkMatter/JProfile/convolution.py:112, in generateConvolvedJ(dwarf, package, filename, irf, gJProf, th2Cut, version, seed, return_array, save_array, ext, step, verbose, **kwargs)
#     109 if int((en/10**minE)*100)<99 or (en >= 10**maxE):
#     110     continue
# --> 112 J, J2D = calcHKConvJProf2D(gJProf, PSF, en=en, package=package, ext=ext, th2Cut=th2Cut, dwarf=dwarf)
#     114 convJ1D_array.append([en, J])
#     116 convJ2D_array[en] = J2D[J2D[:,0]<=(thCut+th_width)]
#
# File ~/Research/scripts/dm_analysis/DarkMatter/JProfile/convolution.py:172, in calcHKConvJProf2D(gJProf, PSF, en, step, package, th2Cut, ext, dwarf, verbose)
#     170 h_dJ = gJProf[:,1]
#     171 h_psf = gPSF1D[:,1]
# --> 172 h_kr, ht_psf=qdht(th_rad, h_psf)      # forward Hankel Transform of PSF
#     173 h_kr, ht_dJ=qdht(th_rad, h_dJ)      # forward Hankel Transform of J factor
#     175 # convolve
#
# File ~/Software/miniconda3/envs/dm/lib/python3.10/site-packages/pyhank/one_shot.py:32, in qdht(r, f, order, axis)
#       8 def qdht(r: np.ndarray, f: np.ndarray, order: int = 0, axis: int = -2) -> Tuple[np.ndarray, np.ndarray]:
#       9     """Perform a quasi-discrete Hankel transform of the function ``f`` (sampled at points
#      10     ``r``) and return the transformed function and its sample points in :math:`k`-space.
#      11
#    (...)
#      30     :rtype: (:class:`numpy.ndarray`, :class:`numpy.ndarray`)
#      31     """
# ---> 32     transformer = HankelTransform(order=order, radial_grid=r)
#      33     f_transform = transformer.to_transform_r(f, axis=axis)
#      34     ht = transformer.qdht(f_transform, axis=axis)
#
# File ~/Software/miniconda3/envs/dm/lib/python3.10/site-packages/pyhank/hankel.py:114, in HankelTransform.__init__(self, order, max_radius, n_points, radial_grid, k_grid)
#     111 self.S = self.alpha_n1
#     113 # Calculate hankel matrix and vectors
# --> 114 jp = scipy_bessel.jv(order, (self.alpha[:, np.newaxis] @ self.alpha[np.newaxis, :]) / self.S)
#     115 jp1 = np.abs(scipy_bessel.jv(order + 1, self.alpha))
#     116 self.T = 2 * jp / ((jp1[:, np.newaxis] @ jp1[np.newaxis, :]) * self.S)
#
# KeyboardInterrupt:

# %%
plotExpULcurve("wino_nlo_exp", label="Null hypothesis")
plotULcurve("wino_nlo", label="WINO (Segue 1; 126 hours)", addRelic=True)
#plotPublication("tt", print_chan=False)
plt.legend(loc=2)
plt.savefig("with_obs.png")

# %%
plotExpULcurve("wino_nlo_exp", label="Null hypothesis")
plotULcurve("wino_nlo", label="WINO (Segue 1; 126 hours)", addRelic=True)
plotPublication("tt", print_chan=False)
plt.legend(loc=2)
plt.savefig("with_obs_pub.png")

# %%
plotExpULcurve("wino_nlo_exp", label="Null hypothesis", addRelic=True)
#plotULcurve("wino_nlo", label="Segue 1 (126 hours)")
plt.legend(loc=2)
plt.savefig("without_obs.png")

# %%
plotULcurve("wino_res_lo", add_input="wino_res_hi", label="Fine resolution")
plotULcurve("wino_nlo", label="Coarse resolution")
plt.ylim(8e-26, 5e-24)
plt.legend(loc=2, fontsize=15)

# %%
Likelihood.calcExpectedLimits("Segue_1", "wino", package="EventDisplay", method=2, ext=True, DM_spectra="WINO",
                            mass=mass, addTheta=False, averagedIRF=True, useBias=True, 
                            correction=True, bkgModel="gaus", filename="wino_res_lo", runs=300)
# Out:
# ==================================================
# [Log] Package      : EventDisplay
# [Log] Dwarf        : Segue_1
# [Log] Channel      : wino
# [Log] Dispersion   : Etr vs ratio
# [Log] Minimum mass : 800 GeV
# [Log] Maximum mass : 56 TeV
# ==================================================
#           x                    dNdE          mass
# ---------------------- -------------------- -----
# Length = 50 rows
#           x                     dNdE            mass
# ---------------------- ---------------------- -------
#                 0.0001      85.14808093354392 55500.0
# 0.00012067926406393288      76.12395839282824 55500.0
# 0.00014563484775012445      67.91355376949309 55500.0
# 0.00017575106248547912      60.45660970281748 55500.0
# 0.00021209508879201905      53.67325931977566 55500.0
#  0.0002559547922699536     47.508904331418535 55500.0
# 0.00030888435964774815      41.91373201361352 55500.0
#                    ...                    ...     ...
#    0.32374575428176433  0.0005817317098449458 55500.0
#     0.3906939937054613  0.0003777194568574485 55500.0
#    0.47148663634573895    0.00028457316917815 55500.0
#     0.5689866029018293 0.00025329506371616505 55500.0
#     0.6866488450042998  0.0002670813879272126 55500.0
#     0.8286427728546842  0.0003768911071682256 55500.0
#                    1.0  2.971370929037945e-05 55500.0
# Length = 50 rows
#           x                     dNdE            mass
# ---------------------- ---------------------- -------
#                 0.0001      85.14808093354392 55500.0
# 0.00012067926406393288      76.12395839282824 55500.0
# 0.00014563484775012445      67.91355376949309 55500.0
# 0.00017575106248547912      60.45660970281748 55500.0
# 0.00021209508879201905      53.67325931977566 55500.0
#  0.0002559547922699536     47.508904331418535 55500.0
# 0.00030888435964774815      41.91373201361352 55500.0
#                    ...                    ...     ...
#    0.32374575428176433  0.0005817317098449458 55500.0
#     0.3906939937054613  0.0003777194568574485 55500.0
#    0.47148663634573895    0.00028457316917815 55500.0
#     0.5689866029018293 0.00025329506371616505 55500.0
#     0.6866488450042998  0.0002670813879272126 55500.0
#     0.8286427728546842  0.0003768911071682256 55500.0
#                    1.0  2.971370929037945e-05 55500.0
# Length = 50 rows
#   0%|          | 0/300 [00:00<?, ?it/s]
# [Log] Expected-upper-limits are saved in '/Users/dtak/Research/DarkMatter/Output/wino_res_lo.npy'
#   FUNCTION VALUE DOES NOT SEEM TO DEPEND ON ANY OF THE 2 VARIABLE PARAMETERS.
#           VERIFY THAT STEP SIZES ARE BIG ENOUGH AND CHECK FCN LOGIC.
#  *******************************************************************************
#  *******************************************************************************

# %%
Likelihood.plotExpULcurve("wino_res_lo", units="TeV")
Likelihood.plotExpULcurve("wino_res_hi", units="TeV")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Likelihood.plotULcurve("EventDisplay_Segue_1_tt", units="TeV", label=const.ListOfChannelLabel["tt"])
Likelihood.plotULcurve("EventDisplay_Segue_1_bbar", units="TeV", label=const.ListOfChannelLabel["bbar"])
Likelihood.plotULcurve("EventDisplay_Segue_1_gamma", units="TeV", label=const.ListOfChannelLabel["gamma"])
Likelihood.plotULcurve("EventDisplay_Segue_1_wino_1D_gaus", addRelic=True, units="TeV", label="Wino")
plt.ylim(1e-27, 1e-19)
plt.legend(loc=2, frameon=False)

# %%
#Likelihood.plotULcurve("test", units="TeV", label='PPPC', ls=":")
Likelihood.plotULcurve("wino_old", addRelic=False, units="TeV", label="Wino (OLD)")
Likelihood.plotULcurve("wino_nlo", addRelic=True, units="TeV", label="Wino (NLO)")
Likelihood.plotULcurve("gamma", units="TeV", label="gamma", ls=":")
plt.ylim(1e-27, 1e-19)
plt.legend(loc=2, frameon=False)
plt.savefig("for_reference.pdf")
