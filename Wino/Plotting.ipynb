# %%
# %load_ext autoreload
# %autoreload 2

from DarkMatter import *
# Out:
# Welcome to JupyROOT 6.26/08

# %% [markdown]
# ## Wino

# %%
plotULcurve("wino_final_all",  label="WINO (all dSphs)", units="TeV")
plotULcurve("wino_UMa_II", label="WINO (UMa II)", units="TeV")

plotPredictedLine(units="TeV", color="r", ls=":")
plt.legend()

# %% [markdown]
# ## Quintuplet

# %%
plotULcurve("quintuplet_final_all", label="Quintuplet (all dSphs)", units="TeV")
plotULcurve("quintuplet_UMa_II", label="Quintuplet (UMa II)", units="TeV")

plotPredictedLine(color="r", quintuplet=True, label="Quintuplet prediction", units="TeV")
plt.legend(loc=1)

# %%
plotULcurve("wino_no_eshift_final", label="Unshifted")
plotULcurve("wino_eshift_final", label="Shifted")

plt.legend(loc=1)
